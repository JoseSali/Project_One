# %%
import pandas as pd
import numpy as np

# %%
data_2010 = pd.read_csv('Resources/ghe2010csv.csv', header = 6)
data_2015 = pd.read_csv('Resources/ghe2015csv.csv', header = 6)
data_2019 = pd.read_csv('Resources/ghe2019csv.csv', header = 6)

data_2010.head()
# Out:
#        Sex  GHE code Unnamed: 2  \
# 0      NaN       NaN        NaN
# 1      NaN       NaN        NaN
# 2  Persons       NaN        NaN
# 3  Persons       0.0        NaN
# 4  Persons      10.0         I.
#
#                                            GHE cause Unnamed: 4 Unnamed: 5  \
# 0                                                NaN        NaN        NaN
# 1                                                NaN        NaN        NaN
# 2                              Population ('000) (2)        NaN        NaN
# 3                                         All Causes        NaN        NaN
# 4  Communicable, maternal, perinatal and nutritio...        NaN        NaN
#
#   Member State\n(See Notes for explanation of colour codes) Afghanistan  \
# 0                                         ISO-3 Code                AFG
# 1                                                NaN                  4
# 2                                                NaN             29,186
# ...

# %%
data_2015.head()
# Out:
#        Sex  GHE code Unnamed: 2  \
# 0      NaN       NaN        NaN
# 1      NaN       NaN        NaN
# 2  Persons       NaN        NaN
# 3  Persons       0.0        NaN
# 4  Persons      10.0         I.
#
#                                            GHE cause Unnamed: 4 Unnamed: 5  \
# 0                                                NaN        NaN        NaN
# 1                                                NaN        NaN        NaN
# 2                              Population ('000) (2)        NaN        NaN
# 3                                         All Causes        NaN        NaN
# 4  Communicable, maternal, perinatal and nutritio...        NaN        NaN
#
#   Member State\n(See Notes for explanation of colour codes) Afghanistan  \
# 0                                         ISO-3 Code                AFG
# 1                                                NaN                  4
# 2                                                NaN             34,414
# ...

# %%
data_2019.head()
# Out:
#        Sex  GHE code Unnamed: 2  \
# 0      NaN       NaN        NaN
# 1      NaN       NaN        NaN
# 2  Persons       NaN        NaN
# 3  Persons       0.0        NaN
# 4  Persons      10.0         I.
#
#                                            GHE cause Unnamed: 4 Unnamed: 5  \
# 0                                                NaN        NaN        NaN
# 1                                                NaN        NaN        NaN
# 2                              Population ('000) (2)        NaN        NaN
# 3                                         All Causes        NaN        NaN
# 4  Communicable, maternal, perinatal and nutritio...        NaN        NaN
#
#   Member State\n(See Notes for explanation of colour codes) Afghanistan  \
# 0                                         ISO-3 Code                AFG
# 1                                                NaN                  4
# 2                                                NaN             38,042
# ...

# %%
data_2010.columns
# Out:
# Index(['Sex', 'GHE code', 'Unnamed: 2', 'GHE cause', 'Unnamed: 4',
#        'Unnamed: 5',
#        'Member State\n(See Notes for explanation of colour codes)',
#        'Afghanistan', 'Albania', 'Algeria',
#        ...
#        'United Republic of Tanzania', 'United States of America', 'Uruguay',
#        'Uzbekistan', 'Vanuatu', 'Venezuela (Bolivarian Republic of)',
#        'Viet Nam', 'Yemen', 'Zambia', 'Zimbabwe'],
#       dtype='object', length=190)

# %%
data_2015.columns
# Out:
# Index(['Sex', 'GHE code', 'Unnamed: 2', 'GHE cause', 'Unnamed: 4',
#        'Unnamed: 5',
#        'Member State\n(See Notes for explanation of colour codes)',
#        'Afghanistan', 'Albania', 'Algeria',
#        ...
#        'United Republic of Tanzania', 'United States of America', 'Uruguay',
#        'Uzbekistan', 'Vanuatu', 'Venezuela (Bolivarian Republic of)',
#        'Viet Nam', 'Yemen', 'Zambia', 'Zimbabwe'],
#       dtype='object', length=190)

# %%
data_2019.columns
# Out:
# Index(['Sex', 'GHE code', 'Unnamed: 2', 'GHE cause', 'Unnamed: 4',
#        'Unnamed: 5',
#        'Member State\n(See Notes for explanation of colour codes)',
#        'Afghanistan', 'Albania', 'Algeria',
#        ...
#        'United Republic of Tanzania', 'United States of America', 'Uruguay',
#        'Uzbekistan', 'Vanuatu', 'Venezuela (Bolivarian Republic of)',
#        'Viet Nam', 'Yemen', 'Zambia', 'Zimbabwe'],
#       dtype='object', length=190)

# %%
data_2010.columns = data_2010.columns.str.replace('Unnamed: 4', 'Cause Category').str.replace('Unnamed: 5', 'Disease/Injury').str.replace('Member State\n(See Notes for explanation of colour codes)', 'Condition')
data_2010
# Out:
#          Sex  GHE code Unnamed: 2  \
# 0        NaN       NaN        NaN
# 1        NaN       NaN        NaN
# 2    Persons       NaN        NaN
# 3    Persons       0.0        NaN
# 4    Persons      10.0         I.
# ..       ...       ...        ...
# 616  Females    1590.0        NaN
# 617  Females    1600.0        NaN
# 618  Females    1610.0        NaN
# 619  Females    1620.0        NaN
# 620  Females    1630.0        NaN
#
#                                              GHE cause        Cause Category  \
# 0                                                  NaN                   NaN
# 1                                                  NaN                   NaN
# 2                                Population ('000) (2)                   NaN
# 3                                           All Causes                   NaN
# 4    Communicable, maternal, perinatal and nutritio...                   NaN
# ..                                                 ...                   ...
# ...

# %%
data_2015.columns = data_2015.columns.str.replace('Unnamed: 4', 'Cause Category').str.replace('Unnamed: 5', 'Disease/Injury').str.replace('Member State\n(See Notes for explanation of colour codes)', 'Condition')
data_2015
# Out:
#          Sex  GHE code Unnamed: 2  \
# 0        NaN       NaN        NaN
# 1        NaN       NaN        NaN
# 2    Persons       NaN        NaN
# 3    Persons       0.0        NaN
# 4    Persons      10.0         I.
# ..       ...       ...        ...
# 616  Females    1590.0        NaN
# 617  Females    1600.0        NaN
# 618  Females    1610.0        NaN
# 619  Females    1620.0        NaN
# 620  Females    1630.0        NaN
#
#                                              GHE cause        Cause Category  \
# 0                                                  NaN                   NaN
# 1                                                  NaN                   NaN
# 2                                Population ('000) (2)                   NaN
# 3                                           All Causes                   NaN
# 4    Communicable, maternal, perinatal and nutritio...                   NaN
# ..                                                 ...                   ...
# ...

# %%
data_2019.columns = data_2019.columns.str.replace('Unnamed: 4', 'Cause Category').str.replace('Unnamed: 5', 'Disease/Injury').str.replace('Member State\n(See Notes for explanation of colour codes)', 'Condition')
data_2019
# Out:
#          Sex  GHE code Unnamed: 2  \
# 0        NaN       NaN        NaN
# 1        NaN       NaN        NaN
# 2    Persons       NaN        NaN
# 3    Persons       0.0        NaN
# 4    Persons      10.0         I.
# ..       ...       ...        ...
# 616  Females    1590.0        NaN
# 617  Females    1600.0        NaN
# 618  Females    1610.0        NaN
# 619  Females    1620.0        NaN
# 620  Females    1630.0        NaN
#
#                                              GHE cause        Cause Category  \
# 0                                                  NaN                   NaN
# 1                                                  NaN                   NaN
# 2                                Population ('000) (2)                   NaN
# 3                                           All Causes                   NaN
# 4    Communicable, maternal, perinatal and nutritio...                   NaN
# ..                                                 ...                   ...
# ...

# %%
data_2010 = data_2010[['Sex', 'GHE cause', 'Cause Category',
       'Disease/Injury',
       'Condition', 'Germany', 'Netherlands','Switzerland','United Kingdom', 'United States of America',]]
data_2010
# Out:
#          Sex                                          GHE cause  \
# 0        NaN                                                NaN
# 1        NaN                                                NaN
# 2    Persons                              Population ('000) (2)
# 3    Persons                                         All Causes
# 4    Persons  Communicable, maternal, perinatal and nutritio...
# ..       ...                                                ...
# 616  Females                                                NaN
# 617  Females                                                 B.
# 618  Females                                                NaN
# 619  Females                                                NaN
# 620  Females                                                NaN
#
#            Cause Category                              Disease/Injury  \
# 0                     NaN                                         NaN
# ...

# %%
data_2015 = data_2015[['Sex', 'GHE cause', 'Cause Category',
       'Disease/Injury',
       'Condition', 'Germany', 'Netherlands','Switzerland','United Kingdom', 'United States of America',]]
data_2015
# Out:
#          Sex                                          GHE cause  \
# 0        NaN                                                NaN
# 1        NaN                                                NaN
# 2    Persons                              Population ('000) (2)
# 3    Persons                                         All Causes
# 4    Persons  Communicable, maternal, perinatal and nutritio...
# ..       ...                                                ...
# 616  Females                                                NaN
# 617  Females                                                 B.
# 618  Females                                                NaN
# 619  Females                                                NaN
# 620  Females                                                NaN
#
#            Cause Category                              Disease/Injury  \
# 0                     NaN                                         NaN
# ...

# %%
data_2019 = data_2019[['Sex', 'GHE cause', 'Cause Category',
       'Disease/Injury',
       'Condition', 'Germany', 'Netherlands','Switzerland','United Kingdom', 'United States of America',]]
data_2019
# Out:
#          Sex                                          GHE cause  \
# 0        NaN                                                NaN
# 1        NaN                                                NaN
# 2    Persons                              Population ('000) (2)
# 3    Persons                                         All Causes
# 4    Persons  Communicable, maternal, perinatal and nutritio...
# ..       ...                                                ...
# 616  Females                                                NaN
# 617  Females                                                 B.
# 618  Females                                                NaN
# 619  Females                                                NaN
# 620  Females                                                NaN
#
#            Cause Category                              Disease/Injury  \
# 0                     NaN                                         NaN
# ...

# %%
data_2010['Sex'].unique()
# Out:
# array([nan, 'Persons', 'Males', 'Females'], dtype=object)

# %%
data_2015['Sex'].unique()
# Out:
# array([nan, 'Persons', 'Males', 'Females'], dtype=object)

# %%
data_2019['Sex'].unique()
# Out:
# array([nan, 'Persons', 'Males', 'Females'], dtype=object)

# %%
data_2010.loc[data_2010['Sex']=='Persons']
# Out:
#          Sex                                          GHE cause  \
# 2    Persons                              Population ('000) (2)
# 3    Persons                                         All Causes
# 4    Persons  Communicable, maternal, perinatal and nutritio...
# 5    Persons                                                 A.
# 6    Persons                                                NaN
# ..       ...                                                ...
# 202  Persons                                                NaN
# 203  Persons                                                 B.
# 204  Persons                                                NaN
# 205  Persons                                                NaN
# 206  Persons                                                NaN
#
#                         Cause Category  \
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
# ...

# %%
data_2015.loc[data_2015['Sex']=='Persons']
# Out:
#          Sex                                          GHE cause  \
# 2    Persons                              Population ('000) (2)
# 3    Persons                                         All Causes
# 4    Persons  Communicable, maternal, perinatal and nutritio...
# 5    Persons                                                 A.
# 6    Persons                                                NaN
# ..       ...                                                ...
# 202  Persons                                                NaN
# 203  Persons                                                 B.
# 204  Persons                                                NaN
# 205  Persons                                                NaN
# 206  Persons                                                NaN
#
#                         Cause Category  \
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
# ...

# %%
data_2019.loc[data_2019['Sex']=='Persons']
# Out:
#          Sex                                          GHE cause  \
# 2    Persons                              Population ('000) (2)
# 3    Persons                                         All Causes
# 4    Persons  Communicable, maternal, perinatal and nutritio...
# 5    Persons                                                 A.
# 6    Persons                                                NaN
# ..       ...                                                ...
# 202  Persons                                                NaN
# 203  Persons                                                 B.
# 204  Persons                                                NaN
# 205  Persons                                                NaN
# 206  Persons                                                NaN
#
#                         Cause Category  \
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
# ...

# %%
data_2010_summary = data_2010.loc[data_2010['Sex']=='Persons']
data_2010_summary
# Out:
#          Sex                                          GHE cause  \
# 2    Persons                              Population ('000) (2)
# 3    Persons                                         All Causes
# 4    Persons  Communicable, maternal, perinatal and nutritio...
# 5    Persons                                                 A.
# 6    Persons                                                NaN
# ..       ...                                                ...
# 202  Persons                                                NaN
# 203  Persons                                                 B.
# 204  Persons                                                NaN
# 205  Persons                                                NaN
# 206  Persons                                                NaN
#
#                         Cause Category  \
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
# ...

# %%
data_2015_summary = data_2015.loc[data_2015['Sex']=='Persons']
data_2015_summary
# Out:
#          Sex                                          GHE cause  \
# 2    Persons                              Population ('000) (2)
# 3    Persons                                         All Causes
# 4    Persons  Communicable, maternal, perinatal and nutritio...
# 5    Persons                                                 A.
# 6    Persons                                                NaN
# ..       ...                                                ...
# 202  Persons                                                NaN
# 203  Persons                                                 B.
# 204  Persons                                                NaN
# 205  Persons                                                NaN
# 206  Persons                                                NaN
#
#                         Cause Category  \
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
# ...

# %%
data_2019_summary = data_2019.loc[data_2019['Sex']=='Persons']
data_2019_summary
# Out:
#          Sex                                          GHE cause  \
# 2    Persons                              Population ('000) (2)
# 3    Persons                                         All Causes
# 4    Persons  Communicable, maternal, perinatal and nutritio...
# 5    Persons                                                 A.
# 6    Persons                                                NaN
# ..       ...                                                ...
# 202  Persons                                                NaN
# 203  Persons                                                 B.
# 204  Persons                                                NaN
# 205  Persons                                                NaN
# 206  Persons                                                NaN
#
#                         Cause Category  \
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
# ...

# %%
data_2010_summary.dtypes
# Out:
# Sex                         object
# GHE cause                   object
# Cause Category              object
# Disease/Injury              object
# Condition                   object
# Germany                     object
# Netherlands                 object
# Switzerland                 object
# United Kingdom              object
# United States of America    object
# dtype: object

# %%
data_2015_summary.dtypes
# Out:
# Sex                         object
# GHE cause                   object
# Cause Category              object
# Disease/Injury              object
# Condition                   object
# Germany                     object
# Netherlands                 object
# Switzerland                 object
# United Kingdom              object
# United States of America    object
# dtype: object

# %%
data_2015_copy = data_2015_summary.copy()

data_2015_copy[columns_to_convert] = data_2015_copy[columns_to_convert].apply(pd.to_numeric, errors='coerce')
data_2015_copy.dtypes
# Out:
# Sex                          object
# GHE cause                    object
# Cause Category               object
# Disease/Injury               object
# Condition                    object
# Germany                     float64
# Netherlands                 float64
# Switzerland                 float64
# United Kingdom              float64
# United States of America    float64
# dtype: object

# %%
data_2019_copy = data_2019_summary.copy()

# Convert specified columns to float 
#data_2019_copy.loc[:, columns_to_convert] = data_2019_copy[columns_to_convert].apply(pd.to_numeric, errors='coerce')
data_2019_copy[columns_to_convert] = data_2019_copy[columns_to_convert].apply(pd.to_numeric, errors='coerce')
data_2019_copy.dtypes
#data_2019_copy.head()
# Out:
# Sex                          object
# GHE cause                    object
# Cause Category               object
# Disease/Injury               object
# Condition                    object
# Germany                     float64
# Netherlands                 float64
# Switzerland                 float64
# United Kingdom              float64
# United States of America    float64
# dtype: object

# %%
data_2019_copy.dtypes
# Out:
# Sex                          object
# GHE cause                    object
# Cause Category               object
# Disease/Injury               object
# Condition                    object
# Germany                     float64
# Netherlands                 float64
# Switzerland                 float64
# United Kingdom              float64
# United States of America    float64
# dtype: object

# %%
data_2010_copy = data_2010_summary.copy()

data_2010_copy[columns_to_convert] = data_2010_copy[columns_to_convert].apply(pd.to_numeric, errors='coerce')
data_2010_copy.dtypes
# Out:
# Sex                          object
# GHE cause                    object
# Cause Category               object
# Disease/Injury               object
# Condition                    object
# Germany                     float64
# Netherlands                 float64
# Switzerland                 float64
# United Kingdom              float64
# United States of America    float64
# dtype: object

# %%
data_2010_copy.head(20)
# Out:
#         Sex                                          GHE cause  \
# 2   Persons                              Population ('000) (2)
# 3   Persons                                         All Causes
# 4   Persons  Communicable, maternal, perinatal and nutritio...
# 5   Persons                                                 A.
# 6   Persons                                                NaN
# 7   Persons                                                NaN
# 8   Persons                                                NaN
# 9   Persons                                                NaN
# 10  Persons                                                NaN
# 11  Persons                                                NaN
# 12  Persons                                                NaN
# 13  Persons                                                NaN
# 14  Persons                                                NaN
# 15  Persons                                                NaN
# ...

# %%
dropped_2010=data_2010_copy.drop(columns=['GHE cause', 'Cause Category', 'Sex', 'Disease/Injury'])
#dropped_2010.dtypes
dropped_2010_data = dropped_2010.dropna(subset=['Condition'])

sorted_2010=dropped_2010_data.sort_values(by='Germany', ascending= False)
sorted_2010.head(20)
#sorted_2010.dtypes
# Out:
#                                   Condition  Germany  Netherlands  \
# 145                        Ischaemic stroke     44.8          6.1
# 146                     Haemorrhagic stroke     18.5          3.3
# 171            Other chronic kidney disease     15.5          1.8
# 158            Cirrhosis due to alcohol use      7.4          0.4
# 99                     Non-Hodgkin lymphoma      6.7          1.3
# 170  Chronic kidney disease due to diabetes      6.6          0.4
# 100                        Multiple myeloma      4.4          0.8
# 159                   Other liver cirrhosis      3.8          0.2
# 77    Liver cancer secondary to alcohol use      3.6          0.3
# 82                  Malignant skin melanoma      3.0          0.9
# 70                            Other pharynx      2.9          0.3
# 68                      Lip and oral cavity      2.6          0.4
# 157            Cirrhosis due to hepatitis C      2.4          0.1
# ...

# %%
# data_2010_summary.iloc[2:, 6:11] = data_2010_summary.iloc[2:, 6:11].replace('', np.nan).astype(float)

# %%
# # Replace non-numeric values with NaN in data_2010_summary
# data_2010_summary.iloc[2:, 6:11] = data_2010_summary.iloc[2:, 6:11].replace('.', np.nan) 

# # Convert columns to float in data_2010_summary  
# data_2010_summary.iloc[2:, 6:11] = data_2010_summary.iloc[2:, 6:11].astype(float)

# # Print updated data_2010_summary
# print(data_2010_summary)

# %%
# data_2010_summary_copy = data_2010_summary.copy()
# data_2010_summary_copy.iloc[2:, 6:11] = data_2010_summary_copy.iloc[2:, 6:11].replace('.', np.nan).astype(float)

# %%
data_2010_summary.iloc[3:, 5:] = data_2010_summary.iloc[3:, 5:].apply(pd.to_numeric, errors='coerce')

data_2019_summary
# Out:
# C:\Users\hyeco\AppData\Local\Temp\ipykernel_18608\1504335379.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_2010_summary.iloc[3:, 5:] = data_2010_summary.iloc[3:, 5:].apply(pd.to_numeric, errors='coerce')
#          Sex                                          GHE cause  \
# 2    Persons                              Population ('000) (2)
# 3    Persons                                         All Causes
# 4    Persons  Communicable, maternal, perinatal and nutritio...
# 5    Persons                                                 A.
# 6    Persons                                                NaN
# ..       ...                                                ...
# 202  Persons                                                NaN
# ...

# %%
data_2010_summary.dtypes
# Out:
# Sex                         object
# GHE cause                   object
# Cause Category              object
# Disease/Injury              object
# Condition                   object
# Germany                     object
# Netherlands                 object
# Switzerland                 object
# United Kingdom              object
# United States of America    object
# dtype: object

# %%
top_values_2010 = changehere.iloc[6:11, 2:6].apply(lambda x: x.nlargest(12), axis=1)

# %%
for country, values in top_values_2010.iteritems():
    print("Country:", country)
    print(values)
    print()
